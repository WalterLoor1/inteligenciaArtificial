# %% [markdown]
# <a href="https://colab.research.google.com/github/WalterLoor1/inteligenciaArtificial/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
print(df.head())
# Out:
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)

print("Forma del marco de datos:")
print(df.shape)
print("\nPrimeras filas del DataFrame:")
print(df.head())
print("\nÚltimas filas del DataFrame:")
print(df.tail())
print("\nTipos de datos de cada columna:")
print(df.dtypes)
print("\nTipo de marco de datos:")
print(type(df))
# Out:
# Forma del marco de datos:
# (1145586, 5)
#
# Primeras filas del DataFrame:
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499
#
# Últimas filas del DataFrame:
#          station_id        stationname        date daytype  rides
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# Tipos de datos de cada columna:
# station_id      int64
# stationname    object
# date           object
# ...

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
description = df.describe()
print(description)
# Out:
#          station_id         rides
# count  1.145586e+06  1.145586e+06
# mean   4.076649e+04  3.056635e+03
# std    4.490665e+02  3.118576e+03
# min    4.001000e+04  0.000000e+00
# 25%    4.037000e+04  9.630000e+02
# 50%    4.076000e+04  2.004000e+03
# 75%    4.115000e+04  4.025000e+03
# max    4.170000e+04  3.632300e+04

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
min_values = df.min()
max_values = df.max()
print("Minimum values:")
print(min_values)
print("\nMaximum values:")
print(max_values)
# Out:
# Minimum values:
# station_id          40010
# stationname          18th
# date           01/01/2001
# daytype                 A
# rides                   0
# dtype: object
#
# Maximum values:
# station_id          41700
# stationname        Wilson
# date           12/31/2022
# daytype                 W
# rides               36323
# dtype: object

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
print(df.head())
# Out:
#             station_id       stationname daytype  rides
# date
# 2017-12-22       41280    Jefferson Park       W   6104
# 2017-12-18       41000  Cermak-Chinatown       W   3636
# 2017-12-02       40280      Central-Lake       A   1270
# 2017-12-19       40140   Dempster-Skokie       W   1759
# 2017-12-03       40690          Dempster       U    499

# %%
# Paso 1: Importar pandas como pd
import pandas as pd

# Paso 2: Cargar el conjunto de datos desde la URL proporcionada
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)

# Paso 3: Convertir la columna 'date' a formato datetime
df['date'] = pd.to_datetime(df['date'])

# Paso 4: Establecer la columna 'date' como índice del DataFrame
df.set_index('date', inplace=True)

# Paso 5: Ordenar el DataFrame por el índice (fecha) en orden ascendente
df_ordenado = df.sort_index()

# Paso 6: Mostrar el DataFrame ordenado
print("DataFrame ordenado por fecha:")
print(df_ordenado.head())
# Out:
# DataFrame ordenado por fecha:
#             station_id     stationname daytype  rides
# date
# 2001-01-01       41290         Kimball       U    869
# 2001-01-01       40090     Damen-Brown       U    411
# 2001-01-01       40850         Library       U    156
# 2001-01-01       40650  North/Clybourn       U   1156
# 2001-01-01       40290    Ashland/63rd       U    540

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
Garfield_Dan_Ryan = df[df['stationname'] == 'Garfield-Dan Ryan']
sns.set(rc={'figure.figsize':(11, 4)})
plt.plot(Garfield_Dan_Ryan['rides'], linewidth=0.5)
plt.title('Rides at Garfield-Dan Ryan Station')
plt.xlabel('Date')
plt.ylabel('N')
# Out:
# Text(0, 0.5, 'N')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos desde la URL
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Establecer la columna 'date' como índice del DataFrame
df.set_index('date', inplace=True)

# Filtrar los datos para la estación 'Garfield-Dan Ryan'
garfield_dan_ryan = df[df['stationname'] == 'Garfield-Dan Ryan']

# Configurar el tamaño de la figura usando seaborn
sns.set(rc={'figure.figsize':(11, 4)})

# Plotear los datos de la estación 'Garfield-Dan Ryan'
plt.plot(garfield_dan_ryan.index, garfield_dan_ryan['rides'], linewidth=0.5)
plt.title('Rides Over Time for Garfield-Dan Ryan Station')
plt.xlabel('Date')
plt.ylabel('Number of Rides')
plt.grid(True)
plt.show()
